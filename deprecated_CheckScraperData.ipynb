# %%
import json
from pprint import pprint

# %%
with open('data/news__1548800133.html.json') as f:
    data = json.load(f)
pprint(data)
# Out:
# {'authors': [],
#  'date_download': '2019-01-29 22:15:33',
#  'date_modify': '2019-01-29 22:15:33',
#  'date_publish': '2019-01-29 22:15:00',
#  'description': 'A mine in western Poland had to start a rescue operation '
#                 'after it was hit by strong shock waves, trapping some miners '
#                 'beneath the surface.',
#  'filename': 'news__1548800133.html',
#  'image_url': 'https://cdni.rt.com/files/2019.01/article/5c50951fdda4c8d9278b45fa.JPG',
#  'language': 'en',
#  'localpath': '/Users/alexander/news-please-repo//data/2019/01/29/rt.com/news__1548800133.html',
#  'source_domain': 'rt.com',
#  'text': 'A mine in western Poland had to start a rescue operation after it '
#          'was hit by strong shock waves, trapping some miners beneath the '
#          'surface.\n'
#          'While 32 workers were at the Rudna mine in Polkowice at the time the '
#          'tremor hit, the majority were able to quickly evacuate to safety. 14 '
# ...

# %%
with open('data/viral__1548813549.html.json') as f:
    data = json.load(f)
pprint(data)
# Out:
# {'authors': [],
#  'date_download': '2019-01-30 01:59:09',
#  'date_modify': '2019-01-30 01:59:09',
#  'date_publish': '2019-01-30 01:59:00',
#  'description': 'A plane powered entirely by the sun made history in the wee '
#                 'hours of Thursday morning after landing in Spain following a '
#                 '70-hour flight across the Atlantic.',
#  'filename': 'viral__1548813549.html',
#  'image_url': 'https://cdni.rt.com/files/2016.06/article/576ba531c46188550e8b4582.jpg',
#  'language': 'en',
#  'localpath': '/Users/alexander/news-please-repo//data/2019/01/29/rt.com/viral__1548813549.html',
#  'source_domain': 'rt.com',
#  'text': 'A plane powered entirely by the sun made history in the wee hours of '
#          'Thursday morning after landing in Spain following a 70-hour flight '
#          'across the Atlantic.\n'
#          'Solar Impulse 2 flew non-stop from New York to Seville, a key and '
#          'risky leg in the mission to circumnavigate the globe.\n'
# ...
