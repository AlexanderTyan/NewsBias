# %%
from newsapi import NewsApiClient

# %%
# Init
newsapi = NewsApiClient(api_key='409d9859bd7d41529532e5dcce0122e3')


# /v2/everything
all_articles_1 = newsapi.get_everything(sources='bbc-news',
                                        from_param='2018-12-29',
                                        to='2019-01-30',
                                        language='en',
                                        sort_by='publishedAt',
                                        page_size=100,
                                        page=1)

# %%
all_articles_10 = newsapi.get_everything(sources='bbc-news',
                                        from_param='2018-12-29',
                                        to='2019-01-30',
                                        language='en',
                                        sort_by='publishedAt',
                                        page_size=100,
                                        page=10)

# %%
all_articles_10
# Out:
# {'articles': [{'author': 'https://www.facebook.com/bbcnews',
#    'content': "Image copyrightGetty ImagesImage caption\r\n The collision happened over the Rutor glacier in Italy's Aosta Valley on the border with France\r\nAt least five people have died after a helicopter and a light aircraft collided on the border between France and Italy,… [+727 chars]",
#    'description': 'A helicopter and a light aircraft collided in the Italian Alps, killing five people and injuring two.',
#    'publishedAt': '2019-01-25T17:06:19Z',
#    'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'title': 'Five dead in air collision on France-Italy border',
#    'url': 'https://www.bbc.co.uk/news/world-europe-47004710',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/3C9A/production/_105341551_gettyimages-931684128.jpg'},
#   {'author': None,
#    'content': 'The latest five minute news bulletin from BBC World Service.',
# ...

# %%
all_articles_2 = newsapi.get_everything(sources='bbc-news',
                                      from_param='2018-12-29',
                                      to='2019-01-30',
                                      language='en',
                                      sort_by='publishedAt',
                                      page_size=100,
                                      page=2)

# %%
all_articles_2
# Out:
# {'articles': [{'author': 'https://www.facebook.com/bbcnews',
#    'content': "Image caption\r\n Labour's Thangam Debbonaire announces the result\r\nMPs have voted to rule out the UK leaving the EU without a deal.\r\nTory MP Caroline Spelman and Labour MP Jack Dromey tabled the amendment to try to prevent a no deal Brexit, and won the support… [+1040 chars]",
#    'description': 'The Commons voted to rule out a no deal Brexit by 318 to 310, but the vote is non-binding.',
#    'publishedAt': '2019-01-29T20:32:10Z',
#    'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'title': 'Brexit: MPs reject no-deal by 318 to 310 votes',
#    'url': 'https://www.bbc.co.uk/news/uk-politics-47050665',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/16E21/production/_105392739_mediaitem105392737.jpg'},
#   {'author': 'https://www.facebook.com/bbcnews',
# ...
