# %%
# %load_ext autoreload
# %autoreload 2

import unicodecsv as csv
import datetime
import feedparser as fp
import newspaper
import helpers
from newspaper import Source, Article
import multiprocessing 
import pandas as pd

# %%
# %%time
# Compiling papers with using rss information, producing newspaper objects:
all_cnn_papers = helpers.compile_papers(rss_feeds_dict=helpers.CNN_LINKS_DICT)
all_bbc_papers = helpers.compile_papers(rss_feeds_dict=helpers.BBC_LINKS_DICT)
all_fox_papers = helpers.compile_papers(rss_feeds_dict=helpers.FOX_LINKS_DICT)
all_rt_papers = helpers.compile_papers(rss_feeds_dict=helpers.RT_LINKS_DICT)
# No msnbc rss, so can't used this method with msnbc
# Out:
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://rss.cnn.com/rss/cnn_topstories.rss
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://rss.cnn.com/rss/cnn_world.rss
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://rss.cnn.com/rss/cnn_us.rss
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://rss.cnn.com/rss/cnn_allpolitics.rss
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://rss.cnn.com/rss/cnn_tech.rss
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://rss.cnn.com/rss/cnn_health.rss
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://rss.cnn.com/rss/cnn_showbiz.rss
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://rss.cnn.com/rss/cnn_travel.rss
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://rss.cnn.com/rss/cnn_latest.rss
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.bbci.co.uk/news/rss.xml
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.bbci.co.uk/news/world/rss.xml
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.bbci.co.uk/news/world/us_and_canada/rss.xml
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.bbci.co.uk/news/uk/rss.xml
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.bbci.co.uk/news/business/rss.xml
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.bbci.co.uk/news/technology/rss.xml
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.bbci.co.uk/news/science_and_environment/rss.xml
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.bbci.co.uk/news/entertainment_and_arts/rss.xml
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.bbci.co.uk/news/health/rss.xml
# [Parse lxml ERR] Document is empty
# [Source parse ERR] http://www.feeds.foxnews.com/foxnews/latest
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.foxnews.com/foxnews/most-popular
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.foxnews.com/foxnews/entertainment
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.foxnews.com/foxnews/health
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.foxnews.com/foxnews/section/lifestyle
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.foxnews.com/foxnews/politics
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.foxnews.com/foxnews/science
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.foxnews.com/foxnews/sports
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.foxnews.com/foxnews/tech
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.foxnews.com/foxnews/national
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] http://feeds.foxnews.com/foxnews/world
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] https://www.rt.com/rss/
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] https://www.rt.com/rss/news/
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] https://www.rt.com/rss/usa/
# [Parse lxml ERR] Document is empty
# [Source parse ERR] https://www.rt.com/rss/uk/
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] https://www.rt.com/rss/sport/
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] https://www.rt.com/rss/russia/
# [Parse lxml ERR] Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.
# [Source parse ERR] https://www.rt.com/rss/business/
# CPU times: user 6.24 s, sys: 614 ms, total: 6.86 s
# Wall time: 57.1 s

# %%
# %%time
# Download articles, i.e. scrapeoff text and other data:
helpers.art_multithread_downloads(papers=all_cnn_papers, threads_per_source=2)
helpers.art_multithread_downloads(papers=all_bbc_papers, threads_per_source=2)
helpers.art_multithread_downloads(papers=all_fox_papers, threads_per_source=2)
helpers.art_multithread_downloads(papers=all_rt_papers, threads_per_source=2)
# Out:
# CPU times: user 44.2 s, sys: 6.3 s, total: 50.5 s
# Wall time: 5min 18s

# %%
master_paper_list = [all_cnn_papers, 
                     all_bbc_papers,
                     all_fox_papers,
                     all_rt_papers]

# %%
# %%time
# Parse all articles:
for paper_list in master_paper_list:
    for paper in paper_list:
        print("Paper:", paper.url)
        paper.parse_articles()
# Out:
# ('Paper:', 'http://rss.cnn.com/rss/cnn_topstories.rss')
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 33434
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 33437
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 20 bytes but only got 0. Skipping tag 36867
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 20 bytes but only got 0. Skipping tag 36868
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 37377
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 37378
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 37380
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 37381
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 37386
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 41486
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 41487
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:780: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 10.
#   warnings.warn(str(msg))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:780: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 2.
#   warnings.warn(str(msg))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 264 bytes but only got 88. Skipping tag 37510
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 13 bytes but only got 0. Skipping tag 42033
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32 bytes but only got 0. Skipping tag 42034
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 33 bytes but only got 0. Skipping tag 42036
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 11 bytes but only got 0. Skipping tag 42037
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:780: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 264 bytes but only got 148. Skipping tag 37510
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 24 bytes but only got 0. Skipping tag 42036
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 18 bytes but only got 0. Skipping tag 42036
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 264 bytes but only got 84. Skipping tag 37510
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 264 bytes but only got 8. Skipping tag 37510
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:780: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 6.
#   warnings.warn(str(msg))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 4. Skipping tag 33434
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 21 bytes but only got 0. Skipping tag 36867
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 21 bytes but only got 0. Skipping tag 36868
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 264 bytes but only got 56. Skipping tag 37510
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 7 bytes but only got 0. Skipping tag 36880
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 7 bytes but only got 0. Skipping tag 36881
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 7 bytes but only got 0. Skipping tag 36882
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 37122
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 44 bytes but only got 0. Skipping tag 37510
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1135 bytes but only got 856. Skipping tag 270
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6 bytes but only got 0. Skipping tag 271
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 21 bytes but only got 0. Skipping tag 272
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 13 bytes but only got 0. Skipping tag 315
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 18 bytes but only got 0. Skipping tag 33432
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 41988
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 41730
#   " Skipping tag %s" % (size, len(data), tag))
# ('Paper:', 'http://rss.cnn.com/rss/cnn_world.rss')
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2060 bytes but only got 788. Skipping tag 59932
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2060 bytes but only got 1812. Skipping tag 59932
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6928 bytes but only got 188. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 264 bytes but only got 0. Skipping tag 37510
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 33 bytes but only got 0. Skipping tag 42016
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 12 bytes but only got 0. Skipping tag 42037
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2014 bytes but only got 0. Skipping tag 59932
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6928 bytes but only got 1212. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6928 bytes but only got 2236. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6928 bytes but only got 3260. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6928 bytes but only got 4284. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6928 bytes but only got 5308. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6928 bytes but only got 6332. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2014 bytes but only got 32. Skipping tag 59932
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2014 bytes but only got 1056. Skipping tag 59932
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2060 bytes but only got 784. Skipping tag 59932
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2060 bytes but only got 1808. Skipping tag 59932
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8152 bytes but only got 184. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 23 bytes but only got 0. Skipping tag 42036
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8152 bytes but only got 1208. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8152 bytes but only got 2232. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8152 bytes but only got 3256. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8152 bytes but only got 4280. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8152 bytes but only got 5304. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8152 bytes but only got 6328. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8152 bytes but only got 7352. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 264 bytes but only got 224. Skipping tag 37510
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2014 bytes but only got 848. Skipping tag 59932
#   " Skipping tag %s" % (size, len(data), tag))
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2014 bytes but only got 1872. Skipping tag 59932
#   " Skipping tag %s" % (size, len(data), tag))
# ('Paper:', 'http://rss.cnn.com/rss/cnn_us.rss')
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# <ipython-input-5-db73bfc2bfae> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'# Parse all articles:\nfor paper_list in master_paper_list:\n    for paper in paper_list:\n        print("Paper:", paper.url)\n        paper.parse_articles()')
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/decorator.pyc:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/source.pyc in parse_articles(self)
#     345         """
#     346         for index, article in enumerate(self.articles):
# --> 347             article.parse()
#     348
#     349         self.articles = self.purge_articles('body', self.articles)
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/article.pyc in parse(self)
#     224
#     225         if self.config.fetch_images:
# --> 226             self.fetch_images()
#     227
#     228         self.is_parsed = True
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/article.pyc in fetch_images(self)
#     233             meta_img_url = self.extractor.get_meta_img_url(
#     234                 self.url, self.clean_doc)
# --> 235             self.set_meta_img(meta_img_url)
#     236
#     237             imgs = self.extractor.get_img_urls(self.url, self.clean_doc)
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/article.pyc in set_meta_img(self, src_url)
#     399     def set_meta_img(self, src_url):
#     400         self.meta_img = encodeValue(src_url)
# --> 401         self.set_top_img(src_url)
#     402
#     403     def set_top_img(self, src_url):
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/article.pyc in set_top_img(self, src_url)
#     404         if src_url is not None:
#     405             s = images.Scraper(self)
# --> 406             if s.satisfies_requirements(src_url):
#     407                 self.set_top_img_no_ckeck(src_url)
#     408
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/images.pyc in satisfies_requirements(self, img_url)
#     227     def satisfies_requirements(self, img_url):
#     228         dimension = fetch_image_dimension(
# --> 229             img_url, self.useragent, referer=self.url)
#     230         area = self.calculate_area(img_url, dimension)
#     231         return area > minimal_area
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/images.pyc in fetch_image_dimension(url, useragent, referer, retries)
#     170
#     171 def fetch_image_dimension(url, useragent, referer=None, retries=1):
# --> 172     return fetch_url(url, useragent, referer, retries, dimension=True)
#     173
#     174
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/images.pyc in fetch_url(url, useragent, referer, retries, dimension)
#      97
#      98             opener = urllib2.build_opener()
# ---> 99             open_req = opener.open(req, timeout=5)
#     100
#     101             # if we only need the dimension of the image, we may not
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
#     446         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 447                                   '_open', req)
#     448         if result:
#     449             return result
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/urllib2.pyc in https_open(self, req)
#    1239         def https_open(self, req):
#    1240             return self.do_open(httplib.HTTPSConnection, req,
# -> 1241                 context=self._context)
#    1242
#    1243         https_request = AbstractHTTPHandler.do_request_
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1199         else:
#    1200             try:
# -> 1201                 r = h.getresponse(buffering=True)
#    1202             except TypeError: # buffering kw not supported
#    1203                 r = h.getresponse()
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     770                     "non-zero flags not allowed in calls to recv() on %s" %
#     771                     self.__class__)
# --> 772             return self.read(buflen)
#     773         else:
#     774             return self._sock.recv(buflen, flags)
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     657                 v = self._sslobj.read(len, buffer)
#     658             else:
# --> 659                 v = self._sslobj.read(len)
#     660             return v
#     661         except SSLError as x:
#
# SSLError: ('The read operation timed out',)

# %%
# Run when rt_papers fail in previous cell:
for paper in all_fox_papers:
    print("Paper:", paper.url)
    paper.parse_articles()
# Out:
# ('Paper:', 'http://www.feeds.foxnews.com/foxnews/latest')
# ('Paper:', 'http://feeds.foxnews.com/foxnews/most-popular')
# ('Paper:', 'http://feeds.foxnews.com/foxnews/entertainment')
# ('Paper:', 'http://feeds.foxnews.com/foxnews/health')
# ('Paper:', 'http://feeds.foxnews.com/foxnews/section/lifestyle')
# ('Paper:', 'http://feeds.foxnews.com/foxnews/politics')
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# <ipython-input-6-092fb9ffacf5> in <module>()
#       2 for paper in all_fox_papers:
#       3     print("Paper:", paper.url)
# ----> 4     paper.parse_articles()
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/source.pyc in parse_articles(self)
#     345         """
#     346         for index, article in enumerate(self.articles):
# --> 347             article.parse()
#     348
#     349         self.articles = self.purge_articles('body', self.articles)
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/article.pyc in parse(self)
#     224
#     225         if self.config.fetch_images:
# --> 226             self.fetch_images()
#     227
#     228         self.is_parsed = True
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/article.pyc in fetch_images(self)
#     233             meta_img_url = self.extractor.get_meta_img_url(
#     234                 self.url, self.clean_doc)
# --> 235             self.set_meta_img(meta_img_url)
#     236
#     237             imgs = self.extractor.get_img_urls(self.url, self.clean_doc)
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/article.pyc in set_meta_img(self, src_url)
#     399     def set_meta_img(self, src_url):
#     400         self.meta_img = encodeValue(src_url)
# --> 401         self.set_top_img(src_url)
#     402
#     403     def set_top_img(self, src_url):
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/article.pyc in set_top_img(self, src_url)
#     404         if src_url is not None:
#     405             s = images.Scraper(self)
# --> 406             if s.satisfies_requirements(src_url):
#     407                 self.set_top_img_no_ckeck(src_url)
#     408
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/images.pyc in satisfies_requirements(self, img_url)
#     227     def satisfies_requirements(self, img_url):
#     228         dimension = fetch_image_dimension(
# --> 229             img_url, self.useragent, referer=self.url)
#     230         area = self.calculate_area(img_url, dimension)
#     231         return area > minimal_area
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/images.pyc in fetch_image_dimension(url, useragent, referer, retries)
#     170
#     171 def fetch_image_dimension(url, useragent, referer=None, retries=1):
# --> 172     return fetch_url(url, useragent, referer, retries, dimension=True)
#     173
#     174
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/site-packages/newspaper/images.pyc in fetch_url(url, useragent, referer, retries, dimension)
#      97
#      98             opener = urllib2.build_opener()
# ---> 99             open_req = opener.open(req, timeout=5)
#     100
#     101             # if we only need the dimension of the image, we may not
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
#     446         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 447                                   '_open', req)
#     448         if result:
#     449             return result
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/urllib2.pyc in https_open(self, req)
#    1239         def https_open(self, req):
#    1240             return self.do_open(httplib.HTTPSConnection, req,
# -> 1241                 context=self._context)
#    1242
#    1243         https_request = AbstractHTTPHandler.do_request_
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1199         else:
#    1200             try:
# -> 1201                 r = h.getresponse(buffering=True)
#    1202             except TypeError: # buffering kw not supported
#    1203                 r = h.getresponse()
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     770                     "non-zero flags not allowed in calls to recv() on %s" %
#     771                     self.__class__)
# --> 772             return self.read(buflen)
#     773         else:
#     774             return self._sock.recv(buflen, flags)
#
# /Users/alexander/anaconda3/envs/NewsBiasPython2/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     657                 v = self._sslobj.read(len, buffer)
#     658             else:
# --> 659                 v = self._sslobj.read(len)
#     660             return v
#     661         except SSLError as x:
#
# SSLError: ('The read operation timed out',)

# %%
def write_out_articles(newspaper_obj, filepath, writeout_type='conventional'):
    """
    TODO: finish this docstring
    :param newspaper_obj:
    :param filepath: str, filepath, WITHOUT the filename
    :param writeout_type: str, 'custom' or 'conventional'
    :return:
    """
    now = datetime.datetime.now()
    current_date = '{}_{}_{}'.format(str(now.year),
                                     str(now.month),
                                     str(now.day))
    if writeout_type == 'custom':
        csv_name = filepath + current_date + '_' + newspaper_obj.description \
                   + '.csv'
    else:
        csv_name = filepath + current_date + '_' + newspaper_obj.brand + '.csv'
    with open(csv_name, 'w') as outcsv:
        writer = csv.writer(outcsv, encoding='utf-8')
        if writeout_type == 'conventional':
            header = ['source_url', 'url', 'title', 'movies', 'text',
                      'keywords', 'meta_keywords', 'tags', 'authors',
                      'publish_date', 'summary', 'html', 'article_html',
                      'meta_description', 'meta_data', 'canonical_link']
        else:
            header = ['source_url', 'url', 'title', 'movies', 'text',
                             'keywords', 'meta_keywords', 'tags', 'authors',
                             'publish_date', 'summary', 'html', 'article_html',
                             'meta_description', 'meta_data', 'canonical_link',
                             'rss_title', 'rss_link', 'rss_id', 'rss_published',
                             'rss_published_parsed', 'rss_feedburner_origlink',
                             'paper_section_name']
        writer.writerow(header)
        for article in newspaper_obj.articles:
            source_url = article.source_url
            url = article.url
            title = article.title
            movies = article.movies
            text = article.text
            keywords = article.keywords
            meta_keywords = article.meta_keywords
            tags = article.tags
            authors = article.authors
            publish_date = article.published_date
            summary = article.summary
            html = article.html
            article_html = article.article_html
            meta_description = article.meta_description
            meta_data = article.meta_data
            canonical_link = article.canonical_link
            if writeout_type == 'custom':
                rss_title = article.additional_data['rss_title']
                rss_link = article.additional_data['rss_link']
                rss_id = article.additional_data['rss_id']
                rss_published = article.additional_data['rss_published']
                rss_published_parsed = \
                    article.additional_data['rss_published_parsed']
                rss_feedburner_origlink = \
                    article.additional_data['rss_feedburner_origlink']
                data_row = [source_url, url, title, movies, text, keywords,
                            meta_keywords, tags, authors, publish_date,
                            summary, html, article_html, meta_description,
                            meta_data, canonical_link, rss_title, rss_link,
                            rss_id, rss_published, rss_published_parsed,
                            rss_feedburner_origlink,
                            newspaper_obj.description]
            else:
                data_row = [source_url, url, title, movies, text, keywords,
                            meta_keywords, tags, authors, publish_date,
                            summary, html, article_html, meta_description,
                            meta_data, canonical_link]
            writer.writerow(data_row)

# %%
filepath = 'data_extra_2/custom_data_pulls/'

# %%
# %%time
for paper_list in master_paper_list:
    for paper in paper_list:
        write_out_articles(newspaper_obj=paper,
                                   filepath=filepath, 
                                   writeout_type='custom')
# Out:
# CPU times: user 8.67 s, sys: 3.15 s, total: 11.8 s
# Wall time: 12.5 s

# %% [markdown]
# Check for files:

# %%
df = pd.read_csv(filepath + '2019_3_27_rt_main_page.csv')

# %%
df.text
# Out:
# 0     Russiagate hysteria has ushered in a “dark per...
# 1     UFC President Dana White has said that lightwe...
# 2     The conspiracy known as ‘Russiagate’ should ha...
# 3     Engines of a luxury cruise ship that narrowly ...
# 4     People standing up to the music from ‘Star War...
# 5     A sixth Birmingham primary school has suspende...
# 6     US President Donald Trump has warned that Russ...
# 7     A Mi-8 military helicopter with 13 people on b...
# 8     South African middle-distance runner Caster Se...
# 9     A journalist from a leading Austrian broadcast...
# 10    Despite criticism from the US and some EU coun...
# 11    The US increased oil exports by more than 70 p...
# 12    Chancellor Angela Merkel’s Cabinet has agreed ...
# 13    After an eight-year quest, an amatuer astronom...
# 14    Little Baby Brexit has found itself in a preca...
# 15    An NGO co-funded by George Soros was spared pr...
# 16    Despite the fact that they were all heading in...
# 17    UK Prime Minister Theresa May is losing contro...
# 18    Lebanon’s Foreign Minister Gebran Bassil has s...
# 19    The US ban on composite materials to Russia ha...
# 20    After trashing Theresa May’s Brexit deal as a ...
# 21    MOSCOW, 27 MARCH –– RT won gold and two silver...
# 22    Northern Ireland must be treated differently f...
# 23    The unique Tu-134UBL plane, also known as the ...
# 24    Bejing's multi-trillion-dollar Belt and Road I...
# 25    A coalition of opposition parties has urged Eg...
# 26    Ahead of the final season of Game of Thrones, ...
# 27    Australian tennis player Nick Kyrgios has ende...
# 28    Prosecutors in north-eastern Spain have launch...
# 29    The two-day visit of US Secretary of State Mik...
#                             ...
# 70    MMA star Conor McGregor is currently being inv...
# 71    Netizens were up in arms this week grilling CN...
# 72    Afghanistan’s Ministry of Foreign Affairs has ...
# 73    The US troops occupying a 55-km zone in southe...
# 74    Speaking to the audience at AIPAC via satellit...
# 75    Massachusetts’ Amherst College has drawn criti...
# 76    A man who invaded Czech tennis star Petra Kvit...
# 77    As torrential rain and strong winds continue t...
# 78    Russian specialists are in Venezuela as part o...
# 79    The European Commission has ignored US calls t...
# 80    MMA analyst Robin Black says Conor McGregor's ...
# 81    Pope Francis is at the center of a peculiar fi...
# 82    Athens reportedly handed a protest note on Tue...
# 83    Italy’s government coalition partners have sta...
# 84    England's 5-1 win over Montenegro was marred b...
# 85    Chicago prosecutors have dropped criminal char...
# 86    The UN envoy for the Middle East warned Tuesda...
# 87    Czech tennis player Andrea Hlavackova has ridi...
# 88    Algeria’s army chief has called for long-term ...
# 89    The US, on Tuesday, imposed fresh sanctions on...
# 90    The DUP is set to deliver a hammer blow to The...
# 91    Citigroup has joined JPMorgan and Goldman Sach...
# 92    A Turkish police officer fired shots at his co...
# 93    Washington’s sanctions against Moscow have not...
# 94    After Robert Mueller’s ‘no collusion’ report s...
# 95    A 42-year-old gay principal who was fired from...
# 96    NSA whistleblower Edward Snowden has decried t...
# 97    Agence France-Presse (AFP) employees, at a mee...
# 98    The Chinese “Belt and Road” initiative is an i...
# 99    Donald Trump's decision to recognize Israel's ...
# Name: text, Length: 100, dtype: object
